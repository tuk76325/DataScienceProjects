# %%
#Question 1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('insurance.csv')
df.info()


#age, bmi, children, and charges are numerical
#sex, smoker, and region are categorical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#Question 2
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Question 3
df.hist(bins=25, figsize=(20,15))
plt.show()

# %%
#Question 4
dfcorr = df.corr()
dfcorr.style.background_gradient()
# Out:
# C:\Users\Toshan\AppData\Local\Temp\ipykernel_16448\1714868447.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfcorr = df.corr()
# <style type="text/css">
# #T_05e71_row0_col0, #T_05e71_row1_col1, #T_05e71_row2_col2, #T_05e71_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_05e71_row0_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_05e71_row0_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_05e71_row0_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_05e71_row1_col0 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_05e71_row1_col2, #T_05e71_row2_col0, #T_05e71_row2_col1, #T_05e71_row2_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_05e71_row1_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_05e71_row3_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_05e71_row3_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_05e71_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_05e71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05e71_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_05e71_level0_col1" class="col_heading level0 col1" >bmi</th>
#       <th id="T_05e71_level0_col2" class="col_heading level0 col2" >children</th>
#       <th id="T_05e71_level0_col3" class="col_heading level0 col3" >charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05e71_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_05e71_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_05e71_row0_col1" class="data row0 col1" >0.109272</td>
#       <td id="T_05e71_row0_col2" class="data row0 col2" >0.042469</td>
#       <td id="T_05e71_row0_col3" class="data row0 col3" >0.299008</td>
#     </tr>
#     <tr>
#       <th id="T_05e71_level0_row1" class="row_heading level0 row1" >bmi</th>
#       <td id="T_05e71_row1_col0" class="data row1 col0" >0.109272</td>
#       <td id="T_05e71_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_05e71_row1_col2" class="data row1 col2" >0.012759</td>
#       <td id="T_05e71_row1_col3" class="data row1 col3" >0.198341</td>
#     </tr>
#     <tr>
#       <th id="T_05e71_level0_row2" class="row_heading level0 row2" >children</th>
#       <td id="T_05e71_row2_col0" class="data row2 col0" >0.042469</td>
#       <td id="T_05e71_row2_col1" class="data row2 col1" >0.012759</td>
#       <td id="T_05e71_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_05e71_row2_col3" class="data row2 col3" >0.067998</td>
#     </tr>
#     <tr>
#       <th id="T_05e71_level0_row3" class="row_heading level0 row3" >charges</th>
#       <td id="T_05e71_row3_col0" class="data row3 col0" >0.299008</td>
#       <td id="T_05e71_row3_col1" class="data row3 col1" >0.198341</td>
#       <td id="T_05e71_row3_col2" class="data row3 col2" >0.067998</td>
#       <td id="T_05e71_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Question 5
df['sex'].value_counts().plot(kind='bar')
plt.title('Sex')
plt.show()
df['smoker'].value_counts().plot(kind='bar')
plt.title('Smoker')
plt.show()
df['region'].value_counts().plot(kind='bar')
plt.title('Region')
plt.show()

# %%
#Question 6
labelencoder = LabelEncoder()
df['sex'] = labelencoder.fit_transform(df['sex'])
df['smoker'] = labelencoder.fit_transform(df['smoker'])
df['region'] = labelencoder.fit_transform(df['region'])

# %%
#Question 7
xMin = df.min(axis=0)
xMax = df.max(axis=0)
df = (df-xMin)/(xMax-xMin)
print(df)
# Out:
#            age  sex       bmi  children  smoker    region   charges
# 0     0.021739  0.0  0.321227       0.0     1.0  1.000000  0.251611
# 1     0.000000  1.0  0.479150       0.2     0.0  0.666667  0.009636
# 2     0.217391  1.0  0.458434       0.6     0.0  0.666667  0.053115
# 3     0.326087  1.0  0.181464       0.0     0.0  0.333333  0.333010
# 4     0.304348  1.0  0.347592       0.0     0.0  0.333333  0.043816
# ...        ...  ...       ...       ...     ...       ...       ...
# 1333  0.695652  1.0  0.403820       0.6     0.0  0.333333  0.151299
# 1334  0.000000  0.0  0.429379       0.0     0.0  0.000000  0.017305
# 1335  0.000000  0.0  0.562012       0.0     0.0  0.666667  0.008108
# 1336  0.065217  0.0  0.264730       0.0     0.0  1.000000  0.014144
# 1337  0.934783  0.0  0.352704       0.0     1.0  0.333333  0.447249
#
# [1338 rows x 7 columns]

# %%
#Question 8
df.to_csv('preprocessedInsuranceDoodnauth.csv')
